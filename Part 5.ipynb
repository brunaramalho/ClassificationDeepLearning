# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
# Build the dictionary and replace rare words with UNK token.

vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3084, 12, 6, 195, 2, 3136, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for i in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'as', 'of', 'originated', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.734639
# Nearest to two: futures, generals, monitors, carr, nazarbayev, tucker, stimulant, shambles,
# Nearest to also: ius, fifties, humiliating, instincts, mantra, boreal, ishmael, shrewd,
# Nearest to state: zirconium, satirizing, ostensibly, gonzales, interludes, dummy, barnstorming, assuming,
# Nearest to most: ramjet, banaba, suggestions, kopp, famous, benn, meissen, prester,
# Nearest to who: pyle, cortes, drachma, gprs, batter, overwhelmed, alienate, footprints,
# Nearest to use: averted, piloting, clearer, created, severely, outback, possessive, rejects,
# Nearest to by: thaw, cerberus, death, plumes, rmi, chulainn, commodores, oxidative,
# Nearest to zero: freising, past, monic, kinderhook, sabbath, fortification, levites, agnes,
# Nearest to known: unparalleled, cur, hennessy, silesia, pitch, krishna, azam, alvarado,
# Nearest to if: overfishing, alkane, semitone, skeletons, rummel, beckwith, isadora, readiness,
# Nearest to years: rebellious, additions, formulae, eridu, circulated, shrew, hyper, nicephorus,
# Nearest to his: truncated, shale, counterpart, patristic, congregationalists, roux, horticulture, attesting,
# Nearest to of: brasil, tree, gora, cisneros, vlaams, stwertka, sign, cultivation,
# Nearest to not: insufficiency, reaches, ramone, sniff, enfant, ex, lookout, arafat,
# Nearest to that: clipper, manuals, alligators, trusting, input, aqueducts, washtenaw, inversely,
# Nearest to has: mutilated, federation, tire, fringe, interbreeding, antonine, litres, counterintuitive,
# Average loss at step 2000: 4.374242
# Average loss at step 4000: 3.870778
# Average loss at step 6000: 3.785938
# Average loss at step 8000: 3.685550
# Average loss at step 10000: 3.620832
# Nearest to two: five, four, three, six, eight, seven, zero, nine,
# Nearest to also: it, which, often, mockingbird, edmonds, might, donovan, symmes,
# Nearest to state: buddhist, fisc, humorously, underlying, bcg, autonomic, barnstorming, pickup,
# Nearest to most: ramjet, vrije, meissen, banaba, anatoly, suggestions, nathaniel, progesterone,
# Nearest to who: he, they, she, psychoanalytic, alienate, rightmost, styne, which,
# Nearest to use: yourdon, clearer, overhead, hesitated, created, study, averted, antagonism,
# Nearest to by: was, though, on, theodora, as, with, prohibits, regenerative,
# Nearest to zero: seven, nine, eight, five, six, three, four, two,
# Nearest to known: unparalleled, silesia, seen, freemasons, rosie, thane, azam, krishna,
# Nearest to if: demographics, corrosive, alkane, lynn, isadora, skeletons, schleicher, str,
# Nearest to years: shrew, eridu, neuro, rebellious, hyper, nicephorus, additions, sufficient,
# Nearest to his: their, its, the, s, her, indomitable, chiefs, plaster,
# Nearest to of: in, tectonics, assistive, leakey, for, on, marcantonio, and,
# Nearest to not: they, arafat, it, reaches, generally, insufficiency, often, figurative,
# Nearest to that: clipper, which, this, pynchon, linnaean, yakuza, western, dropping,
# Nearest to has: had, was, is, have, became, reopening, tire, thank,
# Average loss at step 12000: 3.606707
# Average loss at step 14000: 3.565258
# Average loss at step 16000: 3.407014
# Average loss at step 18000: 3.456681
# Average loss at step 20000: 3.543501
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to also: often, which, now, who, it, not, usually, still,
# Nearest to state: fisc, astonishingly, underlying, buddhist, stranded, professionals, draining, cunt,
# Nearest to most: some, governing, more, ramjet, doolittle, vrije, nathaniel, meissen,
# Nearest to who: he, they, which, she, also, styne, psychoanalytic, still,
# Nearest to use: study, yourdon, birding, antagonism, antacids, hesitated, overhead, view,
# Nearest to by: with, were, from, be, painterly, gao, after, for,
# Nearest to zero: six, five, eight, seven, nine, four, three, two,
# Nearest to known: unparalleled, such, seen, thane, silesia, azam, rosie, lewd,
# Nearest to if: when, is, corrosive, saw, though, cathy, str, demographics,
# Nearest to years: days, shrew, lugosi, neuro, sufficient, cmu, additions, eridu,
# Nearest to his: their, her, its, the, plaster, your, indomitable, communicated,
# Nearest to of: for, tectonics, in, mazar, at, extraordinary, same, including,
# Nearest to not: they, it, also, arafat, generally, reaches, often, no,
# Nearest to that: which, clipper, but, however, this, when, what, scribner,
# Nearest to has: had, was, is, have, became, see, coed, articulate,
# Average loss at step 22000: 3.499351
# Average loss at step 24000: 3.491422
# Average loss at step 26000: 3.481226
# Average loss at step 28000: 3.477486
# Average loss at step 30000: 3.503813
# Nearest to two: four, three, one, five, seven, six, eight, nine,
# Nearest to also: often, now, which, still, never, it, geologists, actually,
# Nearest to state: ship, kindness, restriction, buddhist, clr, backplane, sash, fisc,
# Nearest to most: some, more, many, meissen, freyja, governing, use, ramjet,
# Nearest to who: he, they, she, and, which, styne, often, alienate,
# Nearest to use: study, yourdon, prana, birding, most, growling, treatment, chatham,
# Nearest to by: from, as, under, was, and, istria, oort, with,
# Nearest to zero: five, eight, seven, six, nine, four, three, two,
# Nearest to known: used, described, such, available, regarded, unparalleled, seen, gubernatorial,
# Nearest to if: when, though, without, is, where, however, banner, kimmel,
# Nearest to years: days, lugosi, months, shrew, times, outfielders, neuro, centuries,
# Nearest to his: their, her, its, the, my, indomitable, s, your,
# Nearest to of: in, including, for, gora, from, marcantonio, tectonics, mazar,
# Nearest to not: they, generally, often, conduit, it, arafat, there, to,
# Nearest to that: which, clipper, this, however, what, carnivorous, supergirl, pynchon,
# Nearest to has: had, have, is, was, articulate, eelam, organizer, rowboat,
# Average loss at step 32000: 3.504403
# Average loss at step 34000: 3.493889
# Average loss at step 36000: 3.457263
# Average loss at step 38000: 3.303964
# Average loss at step 40000: 3.427771
# Nearest to two: three, four, five, six, seven, one, nine, eight,
# Nearest to also: often, which, still, sometimes, now, usually, never, not,
# Nearest to state: ship, government, territory, restriction, manipulating, fft, cunt, kindness,
# Nearest to most: more, some, many, governing, meissen, use, less, very,
# Nearest to who: he, which, they, often, she, that, also, delighted,
# Nearest to use: study, most, yourdon, treatment, birding, origin, defenseless, aziz,
# Nearest to by: with, when, theodora, umbilical, for, oort, was, as,
# Nearest to zero: five, seven, nine, six, eight, four, three, two,
# Nearest to known: used, such, unparalleled, regarded, described, available, gubernatorial, downgraded,
# Nearest to if: when, though, is, where, hephaestus, for, majapahit, because,
# Nearest to years: days, months, lugosi, year, shrew, times, centuries, outfielders,
# Nearest to his: her, their, its, the, my, your, s, communicated,
# Nearest to of: in, marcantonio, greenman, same, from, including, modena, lder,
# Nearest to not: they, it, generally, never, also, arafat, still, often,
# Nearest to that: which, however, this, clipper, what, who, mould, extrusive,
# Nearest to has: had, have, was, is, articulate, eelam, rowboat, leach,
# Average loss at step 42000: 3.436894
# Average loss at step 44000: 3.457309
# Average loss at step 46000: 3.458626
# Average loss at step 48000: 3.355222
# Average loss at step 50000: 3.381661
# Nearest to two: three, one, six, four, eight, five, seven, zero,
# Nearest to also: often, now, which, still, never, sometimes, largely, actually,
# Nearest to state: government, manipulating, restriction, territory, institutes, ship, kindness, city,
# Nearest to most: more, less, many, use, some, governing, gamble, meissen,
# Nearest to who: he, which, she, they, i, also, never, there,
# Nearest to use: study, most, need, aziz, form, development, origin, treatment,
# Nearest to by: under, was, as, through, from, with, regenerative, zuid,
# Nearest to zero: seven, eight, five, nine, six, four, three, two,
# Nearest to known: used, such, regarded, described, unparalleled, possible, available, noted,
# Nearest to if: when, though, where, containing, although, because, while, is,
# Nearest to years: days, months, times, lugosi, year, centuries, decades, outfielders,
# Nearest to his: their, her, its, my, your, communicated, our, him,
# Nearest to of: in, mazar, bracing, and, including, aquinas, cleartype, same,
# Nearest to not: generally, they, now, usually, never, arafat, still, reaches,
# Nearest to that: which, however, clipper, this, why, mississippian, but, metrodome,
# Nearest to has: had, have, is, was, eelam, rowboat, unravel, involves,
# Average loss at step 52000: 3.437309
# Average loss at step 54000: 3.426437
# Average loss at step 56000: 3.437401
# Average loss at step 58000: 3.399309
# Average loss at step 60000: 3.393826
# Nearest to two: four, three, one, six, five, seven, eight, zero,
# Nearest to also: often, now, never, still, which, geologists, sometimes, usually,
# Nearest to state: government, ship, territory, manipulating, restriction, cunt, morea, climate,
# Nearest to most: many, use, some, more, less, owner, gamble, governing,
# Nearest to who: she, he, which, they, still, never, delighted, often,
# Nearest to use: need, most, study, aziz, yourdon, because, johore, aramaic,
# Nearest to by: with, stripe, without, imitate, as, selectivity, zuid, using,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to known: used, regarded, described, such, unparalleled, possible, called, classified,
# Nearest to if: when, though, where, because, before, although, is, since,
# Nearest to years: days, months, times, decades, year, centuries, lugosi, miles,
# Nearest to his: her, their, its, my, your, plaster, communicated, indomitable,
# Nearest to of: same, in, including, greenman, for, mazar, include, phoenician,
# Nearest to not: still, they, usually, now, generally, arafat, above, never,
# Nearest to that: which, this, what, however, clipper, mississippian, where, there,
# Nearest to has: had, have, was, is, contains, staphylococcus, dependencies, scrip,
# Average loss at step 62000: 3.245333
# Average loss at step 64000: 3.254259
# Average loss at step 66000: 3.406552
# Average loss at step 68000: 3.396044
# Average loss at step 70000: 3.357678
# Nearest to two: three, six, four, five, seven, one, eight, zero,
# Nearest to also: often, now, still, which, never, sometimes, usually, actually,
# Nearest to state: government, city, restriction, territory, refrains, woodrow, inducted, sash,
# Nearest to most: more, less, some, many, use, governing, gamble, all,
# Nearest to who: he, she, which, they, delighted, yielded, never, unknowns,
# Nearest to use: need, most, aziz, study, form, yourdon, johore, synthetic,
# Nearest to by: through, using, without, dacian, gao, in, from, selectivity,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to known: used, regarded, such, described, classified, available, called, defined,
# Nearest to if: when, though, where, because, before, while, although, containing,
# Nearest to years: days, months, decades, centuries, times, year, lugosi, carpetbaggers,
# Nearest to his: her, their, its, my, your, clouded, plaster, our,
# Nearest to of: including, and, sheedy, in, lovejoy, include, for, conceivably,
# Nearest to not: now, still, usually, never, they, generally, traverse, largely,
# Nearest to that: which, however, what, this, but, clipper, mississippian, usually,
# Nearest to has: had, have, is, was, since, contains, seems, modula,
# Average loss at step 72000: 3.375795
# Average loss at step 74000: 3.347405
# Average loss at step 76000: 3.311726
# Average loss at step 78000: 3.355556
# Average loss at step 80000: 3.378419
# Nearest to two: four, three, six, five, seven, one, eight, zero,
# Nearest to also: often, now, still, sometimes, never, which, usually, typically,
# Nearest to state: city, government, territory, restriction, colorado, states, yesterday, inducted,
# Nearest to most: many, some, more, less, governing, all, gamble, use,
# Nearest to who: he, she, often, they, never, still, which, clampett,
# Nearest to use: need, form, most, because, digitization, johore, study, aziz,
# Nearest to by: istria, through, when, zuid, selectivity, rabelais, was, oort,
# Nearest to zero: seven, five, eight, six, four, nine, three, two,
# Nearest to known: used, regarded, defined, classified, described, called, possible, such,
# Nearest to if: when, though, where, because, before, then, did, although,
# Nearest to years: days, months, decades, times, year, centuries, minutes, hours,
# Nearest to his: her, their, my, its, your, our, wrought, plaster,
# Nearest to of: marcantonio, in, inflationary, akbar, including, greenman, despite, mazar,
# Nearest to not: still, usually, now, arafat, they, never, alboin, actually,
# Nearest to that: which, however, clipper, sync, winged, but, this, inge,
# Nearest to has: had, have, is, was, since, includes, modula, having,
# Average loss at step 82000: 3.403352
# Average loss at step 84000: 3.409027
# Average loss at step 86000: 3.394619
# Average loss at step 88000: 3.352345
# Average loss at step 90000: 3.366277
# Nearest to two: three, five, four, six, seven, eight, one, zero,
# Nearest to also: often, which, never, still, now, actually, sometimes, geologists,
# Nearest to state: colorado, city, restriction, government, territory, woodrow, yesterday, states,
# Nearest to most: many, more, some, less, all, governing, several, gamble,
# Nearest to who: he, she, clampett, which, often, never, still, unknowns,
# Nearest to use: need, treatment, most, study, johore, worship, application, hentai,
# Nearest to by: through, without, when, from, zuid, under, while, using,
# Nearest to zero: five, eight, seven, six, nine, three, four, two,
# Nearest to known: used, regarded, described, such, called, cited, classified, available,
# Nearest to if: when, where, though, because, since, after, before, although,
# Nearest to years: days, months, decades, centuries, year, times, minutes, hours,
# Nearest to his: her, their, its, my, your, our, the, wrought,
# Nearest to of: for, in, including, mazar, marcantonio, during, from, include,
# Nearest to not: still, otherwise, now, never, they, we, nearly, disestablished,
# Nearest to that: however, which, what, why, clipper, inge, ruminants, protea,
# Nearest to has: had, have, is, was, since, having, modula, includes,
# Average loss at step 92000: 3.397680
# Average loss at step 94000: 3.254090
# Average loss at step 96000: 3.358349
# Average loss at step 98000: 3.242829
# Average loss at step 100000: 3.359318
# Nearest to two: five, three, four, six, seven, one, eight, zero,
# Nearest to also: never, still, now, often, actually, sometimes, geologists, usually,
# Nearest to state: restriction, colorado, press, yesterday, government, city, morea, orthography,
# Nearest to most: more, less, especially, some, whiz, gamble, use, oldest,
# Nearest to who: he, she, never, still, which, actually, also, what,
# Nearest to use: need, treatment, application, replenishment, most, view, worship, respect,
# Nearest to by: selectivity, using, when, through, including, istria, without, papers,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to known: regarded, used, such, defined, described, classified, seen, cited,
# Nearest to if: when, where, though, before, while, because, for, gassing,
# Nearest to years: days, months, decades, year, centuries, hours, minutes, times,
# Nearest to his: her, their, your, my, its, our, the, s,
# Nearest to of: including, in, scriptural, and, marcantonio, punctuated, espouses, lovejoy,
# Nearest to not: never, now, still, otherwise, they, archons, you, virtually,
# Nearest to that: which, however, what, clipper, this, who, sync, why,
# Nearest to has: had, have, is, was, since, having, includes, contains,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
bag_window = 2  # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     489                 as_ref=input_arg.is_ref,
# --> 490                 preferred_dtype=default_dtype)
#     491           except TypeError as err:
#
# ~\AppData\Local\Continuum\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype)
#     675         if ret is None:
# --> 676           ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     677
#
# ~\AppData\Local\Continuum\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\ops.py in _TensorTensorConversionFunction(t, dtype, name, as_ref)
#     548         "Tensor conversion requested dtype %s for Tensor with dtype %s: %r"
# --> 549         % (dtype.name, t.dtype.name, str(t)))
#     550   return t
#
# ValueError: Tensor conversion requested dtype int32 for Tensor with dtype float32: 'Tensor("sampled_softmax_loss/Slice_1:0", shape=(?, 128), dtype=float32, device=/device:CPU:0)'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-eabe203bfb05> in <module>()
#      31     # Compute the softmax loss, using a sample of the negative labels each time.
#      32     loss = tf.reduce_mean(
# ---> 33         tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),train_labels, num_sampled, vocabulary_size))
#      34
#      35     # Optimizer.
#
# ~\AppData\Local\Continuum\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\nn_impl.py in sampled_softmax_loss(weights, biases, labels, inputs, num_sampled, num_classes, num_true, sampled_values, remove_accidental_hits, partition_strategy, name)
#    1245       remove_accidental_hits=remove_accidental_hits,
#    1246       partition_strategy=partition_strategy,
# -> 1247       name=name)
#    1248   sampled_losses = nn_ops.softmax_cross_entropy_with_logits(
#    1249       labels=labels, logits=logits)
#
# ~\AppData\Local\Continuum\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\nn_impl.py in _compute_sampled_logits(weights, biases, labels, inputs, num_sampled, num_classes, num_true, sampled_values, subtract_log_q, remove_accidental_hits, partition_strategy, name)
#     979     # sampled_w has shape [num_sampled, dim]
#     980     # Apply X*W', which yields [batch_size, num_sampled]
# --> 981     sampled_logits = math_ops.matmul(inputs, sampled_w, transpose_b=True)
#     982
#     983     # Retrieve the true and sampled biases, compute the true logits, and
#
# ~\AppData\Local\Continuum\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\math_ops.py in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, name)
#    1842     else:
#    1843       return gen_math_ops._mat_mul(
# -> 1844           a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#    1845
#    1846
#
# ~\AppData\Local\Continuum\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in _mat_mul(a, b, transpose_a, transpose_b, name)
#    1287   """
#    1288   result = _op_def_lib.apply_op("MatMul", a=a, b=b, transpose_a=transpose_a,
# -> 1289                                 transpose_b=transpose_b, name=name)
#    1290   return result
#    1291
#
# ~\AppData\Local\Continuum\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     524                   "%s type %s of argument '%s'." %
#     525                   (prefix, dtypes.as_dtype(attrs[input_arg.type_attr]).name,
# --> 526                    inferred_from[input_arg.type_attr]))
#     527
#     528           types = [values.dtype]
#
# TypeError: Input 'b' of 'MatMul' Op has type float32 that does not match type int32 of argument 'a'.
